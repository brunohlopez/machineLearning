# %%
from PIL import Image
import sys
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from pytesseract import pytesseract

# %% [markdown]
# ## This is a text notebook where I try to do text recognition on some of the bboxes

# %% [markdown]
# If you don't have pytesseract downloaded and in your path you can do it this way

# %%
path_to_tesseract = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
pytesseract.tesseract_cmd = path_to_tesseract

# %%
test_img_link = r'C:\Users\brunolopez\mldata\manga_scrape\komi\chapter_0_jpg_09.jpg'
img = Image.open(test_img_link)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=728x1062>

# %%
text = pytesseract.image_to_string(img)
text[:-1]
# Out:
# 'What are people with poor communication skills\nlike?\n\nTi £26] Aa\n\nnsap oysnhw\n\nzorevore 209011\n\nEE scr o CB\n\nI nse\n\nRESULT\nOF... MY\nEDUCATION.\n\nfim\nfm\n'

# %%
img.size
# Out:
# (728, 1053)
