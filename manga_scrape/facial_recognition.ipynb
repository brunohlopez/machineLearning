# %%
from PIL import Image
import sys
import os
import cv2
import matplotlib.pyplot as plt
import yoloface
import numpy as np
from yoloface import face_analysis

# %%
test_img_link = r'C:\Users\brunolopez\mldata\manga_scrape\komi\chapter_0_jpg_06.jpg'
test_img = Image.open(test_img_link)

# %%
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=728x1044>

# %% [markdown]
# Let's do some cv2 stuff

# %%
# %matplotlib widget
img = cv2.imread(test_img_link)

plt.imshow(img)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
face = face_analysis()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JYrRT4Xe-NTrxYGhcj_hy7NtL4D2c77v
# To: c:\Users\brunolopez\machineLearning\manga_scrape\.yoloface\yolov3-tiny_face.weights
# 100%|██████████| 34.7M/34.7M [00:01<00:00, 23.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1S4W6mpOQgVvjpPupbhW6rHFjl-OaUR-g
# To: c:\Users\brunolopez\machineLearning\manga_scrape\.yoloface\yolov3_tiny_face.cfg
# 100%|██████████| 2.09k/2.09k [00:00<?, ?B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1EFlRsOA6oGLLBH2VMDOqHSfDI70CDXeW
# To: c:\Users\brunolopez\machineLearning\manga_scrape\.yoloface\face_detection.weights
# 100%|██████████| 246M/246M [00:11<00:00, 21.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZxUmO0B1435taazz8P0Pqjq8r8Rypeip
# To: c:\Users\brunolopez\machineLearning\manga_scrape\.yoloface\face_detection.cfg
# 100%|██████████| 8.34k/8.34k [00:00<00:00, 8.36MB/s]

# %%
img,box,conf=face.face_detection(image_path=test_img_link ,model='full')

# %%
face.show_output(img,box)
# Out:
# <PIL.Image.Image image mode=RGB size=728x1044>
